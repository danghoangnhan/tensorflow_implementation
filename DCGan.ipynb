# %%
from SupervisedLearning.DCGan.DCGAN import DCGan
ganModel = DCGan(data_dir='./data',result='./result')
ganModel.train()
# Out:
# init model completed
# Epoch [1/0], gen_loss: 2.3275, disc_loss: 0.5089, real_score: 0.0795, gen_score: 0.8563
# /home/danieldu/PycharmProjects/machineLearning
# Result Saved!
# Epoch [2/1], gen_loss: 1.8198, disc_loss: 1.0807, real_score: 0.4279, gen_score: 0.7677
# /home/danieldu/PycharmProjects/machineLearning
# Result Saved!
# Epoch [3/2], gen_loss: 3.0200, disc_loss: 0.4930, real_score: 0.0347, gen_score: 0.8914
# /home/danieldu/PycharmProjects/machineLearning
# Result Saved!
# Epoch [4/3], gen_loss: 2.0927, disc_loss: 0.7563, real_score: 0.3400, gen_score: 0.9193
# /home/danieldu/PycharmProjects/machineLearning
# Result Saved!
# Epoch [5/4], gen_loss: 0.7292, disc_loss: 0.8210, real_score: 0.4316, gen_score: 0.8716
# /home/danieldu/PycharmProjects/machineLearning
# Result Saved!
# Epoch [6/5], gen_loss: 4.1102, disc_loss: 0.8417, real_score: 0.0890, gen_score: 0.5571
# /home/danieldu/PycharmProjects/machineLearning
# Result Saved!
# ...
